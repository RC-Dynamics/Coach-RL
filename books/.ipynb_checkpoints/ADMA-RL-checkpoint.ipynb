# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # Draw Board

# %%
height, width = 180, 330
np.random.seed(60)
field = np.ones([height, width, 3]).astype(np.uint8)
field[..., 1] = 255

ball    = [110, 200]
field  = cv2.circle(field.copy(), (ball[1], ball[0]), 5, [255,127,0], -1)

robots = []
for i in range(6):
    if i <= 2:
        color = [255,0,0]
        w_start, w_end = 0, width//2
        h_start, h_end = 0, height//2
    
    else:
        color = [0,0,255]
        w_start, w_end = width//2, width
        h_start, h_end = height//2, height
        
    
    x, y = np.random.randint(w_start, w_end), np.random.randint(0, height)
    robots.append([y, x])
    field = cv2.circle(field.copy(), (x, y), 5, color, -1)
    
    
    field = cv2.putText(field.copy(), str(i), (x,y), cv2.FONT_HERSHEY_PLAIN, 2, (255,255,255))

goal = [height//2, width-5]
field = cv2.circle(field.copy(), (goal[1], goal[0]), 5, (255, 255, 255), -1)
field = cv2.arrowedLine(field.copy(), (ball[1], ball[0]), (goal[1], goal[0]), 2)
    
plt.figure(figsize=(10, 7));plt.title("Simulate Field")
plt.imshow(field)

# %% [markdown]
# # Calculate Param

# %%
sbd = []
for idx in range(len(robots)):
    sbd.append(  np.sqrt((robots[idx][0] - ball[0])**2 + (robots[idx][1] - ball[1])**2)   ) # y

DDB = np.sum(sbd[:3]) - np.sum(sbd[3:])

#Ball Position
dist = np.abs(ball[1] - goal[1])
alfa = np.abs(ball[0] - goal[0])

print(f"D: {dist:03d}, Alfa: {alfa:03d}, DDB: {DDB:0.3f}")
# Out:
# D: 125, Alfa: 020, DDB: 77.840

# %% [markdown]
# # Create Fuzzy Graph

# %%
## ball distance
dist_close, dist_far = np.zeros(330), np.ones(330)

dist_close[:40] = 1
dist_far[:40] = 0

for idx in range(40, 290):
    dist_close[idx] =  1 - ((1/250) * (idx - 40))
    dist_far[idx]   = ((1/250) * (idx - 40))

    
## DDB
   

ddb_near, ddb_far = np.zeros(330), np.ones(330)
y = list(range(-165, 165))
offset = 165

ddb_near[:offset-25] = 1
ddb_far[:25+offset]  = 0

for idx in range(offset-25, offset+25):
    idy = idx + offset
    
    ddb_near[idx] =  1 - ((1/50) * (idx - (offset - 25)))
    ddb_far[idx]  = ((1/50) * (idx - (offset - 25)))

## Y dist between ball and goal (cm)'
bangle_small, bangle_big = np.zeros(180), np.zeros(180)

bangle_big[:35] = 1
bangle_big[60:] = 0
bangle_big[145:] = 1

for idx in range(35, 60):
    bangle_big[idx] = 1 - ((1/(60-35)) * (idx - 35))

for idx in range(110, 145):
    bangle_big[idx] = ((1/(145-110)) * (idx - 110))

bangle_small[:35] = 0
bangle_small[35:145] = 1
bangle_small[145:] = 0 

for idx in range(35, 75):
    bangle_small[idx] = ((1/(75-35)) * (idx - 35))

for idx in range(105, 145):
    bangle_small[idx] = 1 - ((1/(145-105)) * (idx - 105))
        
plt.figure(figsize=(20, 6))

plt.subplot(131)
plt.plot(dist_close, label='Close')
plt.plot(dist_far, label='Far')
plt.xlabel('Distance of ball (cm)')
plt.ylabel('Pertinence')
plt.legend()

plt.subplot(132)
plt.plot(bangle_big, label='Big')
plt.plot(bangle_small, label='Small')
plt.xlabel('Y dist between ball and goal (cm)')
plt.ylabel('Pertinence')
plt.legend()


plt.subplot(133)
plt.plot(ddb_near, label='Close')
plt.plot(ddb_far, label='Far')
plt.xlabel('DDB + 165 (cm)')
plt.ylabel('Pertinence')
plt.legend()
